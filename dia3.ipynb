# %%
print('DIA 3')
# Out:
# DIA 3

# %% [markdown]
# # Primer challenge 👾

# %%
palabra = 'Hola'

def imprimir_palabra():
    print(palabra)

imprimir_palabra()
# Out:
# Hola

# %% [markdown]
# # Segundo Challenge 👾

# %%
def comparador_de_letras(l1, l2):
    while True:
        l1 = input('ingrese una letra')
        l2 = input('ingrese una letra')
        if l1 == l2:
            print('Estas letras son iguales')
            break
        else:
            print('Estas letras no son iguales, intentalo de nuevo')

        
        
        
            
comparador_de_letras(letra1, letra2)
# Out:
# Estas letras no son iguales, intentalo de nuevo
# Estas letras no son iguales, intentalo de nuevo
# Estas letras no son iguales, intentalo de nuevo
# Estas letras no son iguales, intentalo de nuevo
# Estas letras no son iguales, intentalo de nuevo
# Estas letras son iguales

# %% [markdown]
# # Return

# %% [markdown]
# # Tercer challenge 👾

# %%
# Establecer variables para la palabra y el numero utilizando un input (cada uno con su respectivo tipo de dato)
palabra_1 = input('Ingrese una palabra')
numero_1 = int(input('Ingrese un numero'))

#Crear la funcion 
def comparador(ltr, nro):
    if len(ltr) == nro:
        return True 
    else:
        return False


comparador(palabra_1, numero_1)
print(comparador(palabra_1, numero_1))
# Out:
# False

# %% [markdown]
# # Cuarto Challenge 👾

# %%
# Crear la variable de la palabra con un input
palabra_2 = input('Ingrese una palabra...')
letra = 'a'
# Crear la funcion que detecte la letra que elija 
def detector_de_letra(word, letter):
    if word in letter:
        return [word]
    else: 
        return word
        
        
detector_de_letra(letra, palabra_2)
print(detector_de_letra(letra, palabra_2))
print(f'la palabra escrita fue: {palabra_2}')
# Out:
# ['a']
# la palabra escrita fue: carro

# %% [markdown]
# # Quinto challenge 👾

# %%
# Pedir al usuario que ingrese una palabra
palabra_enlistada1 = input('Ingrese la palabra a enlistar')
palabra_enlistada2 = input('Ingrese la palabra a enlistar')
palabra_enlistada3 = input('Ingrese la palabra a enlistar')

palabra_enlistada1 = list(palabra_enlistada1)
palabra_enlistada2 = list(palabra_enlistada2)
palabra_enlistada3 = list(palabra_enlistada3)


palabras_ingresadas = []


palabras_ingresadas.append(palabra_enlistada1)
print(palabras_ingresadas)

palabras_ingresadas.append(palabra_enlistada2)
print(palabras_ingresadas)

palabras_ingresadas.append(palabra_enlistada3)
print(palabras_ingresadas)
# Out:
# [['c', 'a', 's', 'a']]
# [['c', 'a', 's', 'a'], ['a', 'u', 't', 'o']]
# [['c', 'a', 's', 'a'], ['a', 'u', 't', 'o'], ['m', 'o', 't', 'o']]

# %%
palabras_ingresadas1 = []


list_word1 = input('Ingresa una palabra')
list_word1 = list(list_word1)
palabras_ingresadas1.append(list_word1)
print(palabras_ingresadas1)
    
list_word2 = input('Ingresa una palabra')
list_word2 = list(list_word2)
palabras_ingresadas1.append(list_word2)
print(palabras_ingresadas1)

list_word3 = input('Ingresa una palabra')
list_word3 = list(list_word3)
palabras_ingresadas1.append(list_word3)
print(palabras_ingresadas1)
# Out:
# [['h', 'o', 'l', 'i', 's']]
# [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o']]
# [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# %% [markdown]
# # Sexto challenge 👾

# %%
# Imprimir los tres elementos de la lista principal uno debajo del otro utilizando un for

lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

for i in lista:
    print(i)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
